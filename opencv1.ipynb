# %%
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
import cv2

# %%
img = cv2.imread('DATA/00-puppy.jpg')

# %%
type(img)
# Out:
# numpy.ndarray

# %%
img2 = cv2.imread('/wrong/path/image.jpg')
type(img2)
# Out:
# [ WARN:0@815.102] global loadsave.cpp:275 findDecoder imread_('/wrong/path/image.jpg'): can't open/read file: check file path/integrity
# NoneType

# %%
img
# Out:
# array([[[78, 81, 95],
#         [80, 83, 97],
#         [81, 84, 98],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [79, 82, 96],
#         [79, 82, 96],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        [[78, 81, 95],
#         [77, 80, 94],
#         [77, 80, 94],
#         ...,
#         [22, 27, 25],
#         [22, 27, 25],
#         [22, 27, 25]],
#
#        ...,
#
#        [[20, 29, 19],
#         [21, 30, 20],
#         [21, 30, 20],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [21, 30, 20],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]],
#
#        [[21, 30, 20],
#         [20, 29, 19],
#         [20, 29, 19],
#         ...,
#         [22, 30, 23],
#         [23, 31, 24],
#         [23, 31, 24]]], dtype=uint8)

# %%
img.shape
# Out:
# (1300, 1950, 3)

# %%
img2.shape
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[30], line 1
# ----> 1 img2.shape
#
# AttributeError: 'NoneType' object has no attribute 'shape'

# %%
plt.imshow(img)
plt.show()

# %%
# MATPLOTLIB = RGB | RED GREEN BLUE
# OPENCV = BGR | BLUE GREEN RED

# %%
fiximg = cv2.cvtColor(img, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(fiximg)
plt.show()

# %%
img_grey = cv2.imread('DATA/00-puppy.jpg',cv2.IMREAD_GRAYSCALE)

# %%
img_grey.shape
# Out:
# (1300, 1950)

# %%
img_grey.max()
# Out:
# np.uint8(209)

# %%
img_grey.min()
# Out:
# np.uint8(1)

# %%
plt.imshow(img_grey,cmap='gray')
plt.show()

# %%
fiximg.shape
# Out:
# (1300, 1950, 3)

# %%
new_img = cv2.resize(fiximg,( 1000,400))

# %%
plt.imshow(new_img)
plt.show()

# %%
w_ratio = 0.5
h_ratio = 0.5

# %%
newfiximg = cv2.resize(fiximg,(0,0),fiximg,w_ratio,h_ratio )

# %%
plt.imshow(newfiximg)
plt.show()

# %%
new_img = cv2.flip(newfiximg,1) # 0,1,-1
plt.imshow(new_img)
plt.show()

# %%
type(fiximg)
# Out:
# numpy.ndarray

# %%
cv2.imwrite('totally_new_image.jpg',new_img)
# Out:
# True

# %%
fig = plt.figure(figsize=(10,8))
ax = fig.add_subplot(111)
ax.imshow(new_img)
plt.show()
